# %%
from vllm import LLM, SamplingParams

def main():
    print("Loading model...")

    llm = LLM(
        model="facebook/opt-125m",
        enforce_eager=True,          # safer for debugging
        gpu_memory_utilization=0.8,  # fine for a tiny model
    )

    print("Generating...")

    sampling_params = SamplingParams(
        max_tokens=16,
        temperature=0.0,
    )

    outputs = llm.generate(
        ["Hello, world!"],
        sampling_params,
    )

    print("Output:")
    print(outputs[0].outputs[0].text)

if __name__ == "__main__":
    main()
# Out:
# Loading model...
# INFO 04-04 17:52:05 [utils.py:233] non-default args: {'gpu_memory_utilization': 0.8, 'disable_log_stats': True, 'enforce_eager': True, 'model': 'facebook/opt-125m'}
# INFO 04-04 17:52:06 [model.py:549] Resolved architecture: OPTForCausalLM
# INFO 04-04 17:52:06 [model.py:1678] Using max model len 2048
# WARNING 04-04 17:52:06 [vllm.py:848] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# WARNING 04-04 17:52:06 [vllm.py:859] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# INFO 04-04 17:52:06 [vllm.py:1025] Cudagraph is disabled under eager mode
# (EngineCore pid=7231) INFO 04-04 17:52:10 [core.py:105] Initializing a V1 LLM engine (v0.19.0) with config: model='facebook/opt-125m', speculative_config=None, tokenizer='facebook/opt-125m', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=facebook/opt-125m, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'splitting_ops': [], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_images_per_batch': 0, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# (EngineCore pid=7231) WARNING 04-04 17:52:11 [interface.py:525] Using 'pin_memory=False' as WSL is detected. This may slow down the performance.
# (EngineCore pid=7231) INFO 04-04 17:52:11 [parallel_state.py:1400] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.23.197.160:55125 backend=nccl
# (EngineCore pid=7231) INFO 04-04 17:52:13 [parallel_state.py:1716] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=7231) INFO 04-04 17:52:13 [gpu_model_runner.py:4735] Starting to load model facebook/opt-125m...
# (EngineCore pid=7231) INFO 04-04 17:52:14 [cuda.py:334] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=7231) INFO 04-04 17:52:14 [flash_attn.py:596] Using FlashAttention version 2
# Loading pt checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading pt checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  7.83it/s]
# Loading pt checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  7.82it/s]
# (EngineCore pid=7231)
# (EngineCore pid=7231) INFO 04-04 17:52:14 [default_loader.py:384] Loading weights took 0.13 seconds
# (EngineCore pid=7231) INFO 04-04 17:52:15 [gpu_model_runner.py:4820] Model loading took 0.24 GiB memory and 0.817396 seconds
# (EngineCore pid=7231) INFO 04-04 17:52:16 [gpu_worker.py:436] Available KV cache memory: 9.1 GiB
# (EngineCore pid=7231) INFO 04-04 17:52:16 [kv_cache_utils.py:1319] GPU KV cache size: 264,992 tokens
# (EngineCore pid=7231) INFO 04-04 17:52:16 [kv_cache_utils.py:1324] Maximum concurrency for 2,048 tokens per request: 129.39x
# (EngineCore pid=7231) INFO 04-04 17:52:16 [core.py:283] init engine (profile, create kv cache, warmup model) took 1.53 seconds
# (EngineCore pid=7231) INFO 04-04 17:52:17 [vllm.py:790] Asynchronous scheduling is enabled.
# (EngineCore pid=7231) WARNING 04-04 17:52:17 [vllm.py:848] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (EngineCore pid=7231) WARNING 04-04 17:52:17 [vllm.py:859] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (EngineCore pid=7231) INFO 04-04 17:52:17 [vllm.py:1025] Cudagraph is disabled under eager mode
# (EngineCore pid=7231) INFO 04-04 17:52:17 [compilation.py:290] Enabled custom fusions: norm_quant, act_quant
# Generating...
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Output:
#
# Hello, world!
# Hello, world!
# Hello, world!
#
# (EngineCore pid=7231) INFO 04-04 17:52:17 [core.py:1210] Shutdown initiated (timeout=0)
# (EngineCore pid=7231) INFO 04-04 17:52:17 [core.py:1233] Shutdown complete
# [rank0]:[W404 17:52:17.230791624 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
